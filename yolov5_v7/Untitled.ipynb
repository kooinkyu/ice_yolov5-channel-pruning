# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...

# %%
pip install torch-pruning
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.2/70.2 kB 11.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os, math, csv, json
from pathlib import Path
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# === 경로 (네 환경에 맞춰 둔 기본값) ===
REPO = "/home/jovyan/lost+found/ice_sleep_detpj/yolov5_v7"
WEIGHTS_BASE = f"{REPO}/runs/train/ice_eye_mouth20_pruned_finetune_33_40/weights/best.pt"    # 프루닝 전(학습 완료) 가중치
WEIGHTS_SOFT = f"{REPO}/runs/prune/pruned_0.3.pt"                                            # soft pruning 후 가중치(희소화)
OUT_DIR = f"{REPO}/runs/prune/analysis"  # 결과 저장 폴더

os.makedirs(OUT_DIR, exist_ok=True)

# 로드 유틸
def load_yolov5_model(ckpt_path):
    ckpt = torch.load(ckpt_path, map_location='cpu')
    model = ckpt['model'].float().eval()
    return model

model_base = load_yolov5_model(WEIGHTS_BASE)
model_soft = load_yolov5_model(WEIGHTS_SOFT)  # 없으면 이 줄만 주석 처리하고 'soft 없음' 모드로 진행 가능
