# %%
# !git clone https://github.com/VainF/Torch-Pruning.git
# Out:
# Cloning into 'Torch-Pruning'...
# remote: Enumerating objects: 7271, done.
# remote: Counting objects: 100% (169/169), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 7271 (delta 131), reused 107 (delta 107), pack-reused 7102 (from 2)
# Receiving objects: 100% (7271/7271), 10.30 MiB | 19.69 MiB/s, done.
# Resolving deltas: 100% (4842/4842), done.

# %%
# %cd Torch-Pruning
# Out:
# /home/jovyan/lost+found/ice_sleep_detpj/yolov5_v7/Torch-Pruning

# %%
# !pip install -e .
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Obtaining file:///home/jovyan/lost%2Bfound/ice_sleep_detpj/yolov5_v7/Torch-Pruning
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: torch-pruning
#     Found existing installation: torch-pruning 1.6.1
#     Uninstalling torch-pruning-1.6.1:
#       Successfully uninstalled torch-pruning-1.6.1
#   Running setup.py develop for torch-pruning
# ...

# %%
# %cd /home/jovyan/lost+found/ice_sleep_detpj
# Out:
# /home/jovyan/lost+found/ice_sleep_detpj

# %%
# !cp Torch-Pruning/examples/yolov5/detect_after_pruning.py yolov5_v7/
# Out:
# cp: cannot stat 'Torch-Pruning/examples/yolov5/detect_after_pruning.py': No such file or directory

# %%
rm -rf Torch-Pruning

# %%
# !python detect_after_pruning_ice.py
